# %%
from functions.diagram_functions import *
import numpy as np

# %%
points_1st_1 = np.array([[0, -1], [0, 1], [1, 0], [2, 0]])
paths_1st_1 = np.array([[1, 3], [2, 3], [3, 4]]) 

points_1st_2 = np.array([[0, 0], [1, 0], [2, -1], [2, 1]])
paths_1st_2 = np.array([[1, 2], [2, 3], [2, 4]]) 

represent_diagram(points_1st_1, paths_1st_1, index=True)
represent_diagram(points_1st_2, paths_1st_2, index=True)

# %%
points_2nd_1, paths_2nd_1 = connection(points_1st_1, paths_1st_1, points_1st_1, paths_1st_1)

for i in range(len(paths_2nd_1)):
    points_2nd_1_, paths_2nd_1_ = simplify_diagram(points_2nd_1, paths_2nd_1[i])
    represent_diagram(points_2nd_1_, paths_2nd_1_, index=True)

points_2nd_1_1, paths_2nd_1_1 = simplify_diagram(points_2nd_1, paths_2nd_1[0])

# %%
points_2nd_2, paths_2nd_2 = connection(points_1st_2, paths_1st_2, points_1st_1, paths_1st_1)


points_2nd_2_1, paths_2nd_2_1 = simplify_diagram(points_2nd_2, paths_2nd_2[1])
points_2nd_2_2, paths_2nd_2_2 = simplify_diagram(points_2nd_2, paths_2nd_2[4])

# %%
points_2nd_3, paths_2nd_3 = connection(points_1st_1, paths_1st_1, points_1st_2, paths_1st_2)

points_2nd_3, paths_2nd_3 = simplify_diagram(points_2nd_3, paths_2nd_3[0])
represent_diagram(points_2nd_3, paths_2nd_3, index=True)

# %%
points_2nd_4, paths_2nd_4 = connection(points_1st_2, paths_1st_2, points_1st_2, paths_1st_2)

points_2nd_4, paths_2nd_4 = simplify_diagram(points_2nd_4, paths_2nd_4[0])
represent_diagram(points_2nd_4, paths_2nd_4, index=True)

# %%
points_3rd_1, paths_3rd_1 = connection(points_1st_1, paths_1st_1, points_2nd_1_1, paths_2nd_1_1, offset = 0.5)

for i in range(len(paths_3rd_1)):
    points_3rd_1_1, paths_3rd_1_1 = simplify_diagram(points_3rd_1, paths_3rd_1[i])
    represent_diagram(points_3rd_1_1, paths_3rd_1_1, index=True)

# %%
points_3rd_1, paths_3rd_1 = connection(points_1st_2, paths_1st_2, points_2nd_1_1, paths_2nd_1_1, offset = 0.5)

for i in range(len(paths_3rd_1)):
    points_3rd_1_1, paths_3rd_1_1 = simplify_diagram(points_3rd_1, paths_3rd_1[i])
    represent_diagram(points_3rd_1_1, paths_3rd_1_1, index=True)
