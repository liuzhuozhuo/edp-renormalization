# %%
import matplotlib.pyplot as plt

# Define coordinates (just use a list of (x, y) tuples)
coordinates = [(1, 1), (2, 3), (1, 5), (4, 3), (5, 5), (5, 1)]

# Auto-generate names: P₀, P₁, P₂, ...
names = [f"P{i}" for i in range(len(coordinates))]
positions = dict(zip(names, coordinates))

# Define undirected edges using the point names
edges = [('P0', 'P1'), ('P1', 'P2'), ('P1', 'P3'), ('P3', 'P4'), ('P3', 'P5')]

# Plot
plt.figure(figsize=(10, 6))
for name, (x, y) in positions.items():
    plt.plot(x, y, 'o', markersize=8, color='skyblue')
    plt.text(x + 0.1, y + 0.1, f"{name} ({x}, {y})", fontsize=14, color='tab:blue', ha='left', va='bottom')

for u, v in edges:
    x1, y1 = positions[u]
    x2, y2 = positions[v]
    plt.plot([x1, x2], [y1, y2], 'k-')
    mx, my = (x1 + x2) / 2, (y1 + y2) / 2
    plt.text(mx + 0.3, my + 0.1, f"[{u},{v}]", fontsize=14, color='black', ha='center', va='center')

plt.axis('off')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Define coordinates
coordinates = [(1, 1), (2, 3), (1, 5), (4, 3), (5, 5), (5, 1)]

# Auto-generate names: P₀, P₁, ...
names = [f"P{i}" for i in range(len(coordinates))]
positions = dict(zip(names, coordinates))

# Define undirected edges
edges = [('P0', 'P1'), ('P1', 'P2'), ('P1', 'P3'), ('P3', 'P4'), ('P3', 'P5')]

# Plot
plt.figure(figsize=(10, 6))
for name, (x, y) in positions.items():
    plt.plot(x, y, 'o', markersize=8, color='skyblue')
    plt.text(x + 0.1, y + 0.1, f"{name} ({x}, {y})", fontsize=14, color='tab:blue', ha='left', va='bottom')

for u, v in edges:
    x1, y1 = positions[u]
    x2, y2 = positions[v]
    
    # Check for the special edge P1-P3 (or P3-P1)
    if (u == 'P1' and v == 'P3') or (u == 'P3' and v == 'P1'):
        plt.plot([x1, x2], [y1, y2], 'k--', linewidth=2)  # red dashed
    else:
        plt.plot([x1, x2], [y1, y2], 'k-', linewidth=1.5)
    
    mx, my = (x1 + x2) / 2, (y1 + y2) / 2
    plt.text(mx + 0.3, my + 0.1, f"[{u},{v}]", fontsize=14, color='black', ha='center', va='center')

plt.axis('off')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Define coordinates (just use a list of (x, y) tuples)
coordinates = [(1, 1), (2, 3), (1, 5), (3, 3)]

# Auto-generate names: P₀, P₁, P₂, ...
names = [f"P{i}" for i in range(len(coordinates))]
positions = dict(zip(names, coordinates))

# Define undirected edges using the point names
edges = [('P0', 'P1'), ('P1', 'P2'), ('P1', 'P3')]

# Plot
plt.figure(figsize=(8, 6))

for u, v in edges:
    x1, y1 = positions[u]
    x2, y2 = positions[v]
    plt.plot([x1, x2], [y1, y2], 'k-', linewidth=8)

plt.axis('off')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Define coordinates (just use a list of (x, y) tuples)
coordinates = [(3, 1), (2, 3), (3, 5), (1, 3)]

# Auto-generate names: P₀, P₁, P₂, ...
names = [f"P{i}" for i in range(len(coordinates))]
positions = dict(zip(names, coordinates))

# Define undirected edges using the point names
edges = [('P0', 'P1'), ('P1', 'P2'), ('P1', 'P3')]

# Plot
plt.figure(figsize=(8, 6))

for u, v in edges:
    x1, y1 = positions[u]
    x2, y2 = positions[v]
    plt.plot([x1, x2], [y1, y2], 'k-', linewidth=8)

plt.axis('off')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Define coordinates (just use a list of (x, y) tuples)
coordinates = [(1, 1), (2, 3), (1, 5), (3, 3), (4, 1), (5, 3), (4, 5), (6, 3)]

# Auto-generate names: P₀, P₁, P₂, ...
names = [f"P{i}" for i in range(len(coordinates))]
positions = dict(zip(names, coordinates))

# Define undirected edges using the point names
edges = [('P0', 'P1'), ('P1', 'P2'), ('P1', 'P3'), ('P4', 'P5'), ('P5', 'P3'), ('P5', 'P7')]

# Plot
plt.figure(figsize=(16, 6))

for u, v in edges:
    x1, y1 = positions[u]
    x2, y2 = positions[v]
    plt.plot([x1, x2], [y1, y2], 'k-', linewidth=8)

plt.axis('off')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Define coordinates (just use a list of (x, y) tuples)
coordinates = [(3, 1), (2, 3), (3, 5), (1, 3), (3, 1), (4, 3), (3, 5), (5, 3)]

# Auto-generate names: P₀, P₁, P₂, ...
names = [f"P{i}" for i in range(len(coordinates))]
positions = dict(zip(names, coordinates))

# Define undirected edges using the point names
edges = [('P0', 'P1'), ('P1', 'P2'), ('P1', 'P3'), ('P4', 'P5'), ('P5', 'P6'), ('P5', 'P7')]

# Plot
plt.figure(figsize=(16, 6))

for u, v in edges:
    x1, y1 = positions[u]
    x2, y2 = positions[v]
    plt.plot([x1, x2], [y1, y2], 'k-', linewidth=8)

plt.axis('off')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Define coordinates (just use a list of (x, y) tuples)
coordinates = [(3, 1), (2, 3), (3, 5), (1, 3), (4, 1), (5, 3), (4, 5), (6, 3)]

# Auto-generate names: P₀, P₁, P₂, ...
names = [f"P{i}" for i in range(len(coordinates))]
positions = dict(zip(names, coordinates))

# Define undirected edges using the point names
edges = [('P0', 'P1'), ('P1', 'P5'), ('P1', 'P3'), ('P1', 'P5'), ('P5', 'P6'), ('P5', 'P7')]

# Plot
plt.figure(figsize=(16, 6))

for u, v in edges:
    x1, y1 = positions[u]
    x2, y2 = positions[v]
    plt.plot([x1, x2], [y1, y2], 'k-', linewidth=8)

plt.axis('off')
plt.tight_layout()
plt.show()
